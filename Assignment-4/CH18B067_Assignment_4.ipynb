# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#IMPORTS
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix


path = '/content/drive/MyDrive/Sem-7 Books/EE4708/Assignment-4/' ### CHANGE TO PATH OF DATASETS TO RUN

# %%
df = pd.read_csv(path+'car_evaluation.csv', header=None, na_values=[' ?'])
df.columns = ['buying', 'maint', 'doors', 
              'persons', 'lug_boot', 'safety', 'Target']
df.head()
# Out:
#   buying  maint doors persons lug_boot safety Target
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
df.isna().sum()
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# Target      0
# dtype: int64

# %%
### PRINTING ALL UNIQUE VALUES IN EACH COLUMN
for i in df.columns:
  print(i, df[i].nunique())
  print(df[i].unique())
  print("--------------")
# Out:
# buying 4
# ['vhigh' 'high' 'med' 'low']
# --------------
# maint 4
# ['vhigh' 'high' 'med' 'low']
# --------------
# doors 4
# ['2' '3' '4' '5more']
# --------------
# persons 3
# ['2' '4' 'more']
# --------------
# lug_boot 3
# ['small' 'med' 'big']
# --------------
# safety 3
# ['low' 'med' 'high']
# --------------
# Target 4
# ['unacc' 'acc' 'vgood' 'good']
# --------------

# %%
# OBSERVING DETAILS FOR EACH COLUMN
df.describe()
# Out:
#        buying maint doors persons lug_boot safety Target
# count    1728  1728  1728    1728     1728   1728   1728
# unique      4     4     4       3        3      3      4
# top      high  high     4       4      big   high  unacc
# freq      432   432   432     576      576    576   1210

# %%
df.head()
# Out:
#   buying  maint doors persons lug_boot safety Target
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
# DROPPING MISSING VALUES
df.isna().sum()
# df.dropna(inplace=True)
# Out:
# buying      0
# maint       0
# doors       0
# persons     0
# lug_boot    0
# safety      0
# Target      0
# dtype: int64

# %%
# PLOTTING COUNTS OF EACH FEATURE SPLITTING BY TARGET
test_cols = df.columns
for i in test_cols:
  sns.countplot(i, hue='Target', data=df)
  plt.xticks(rotation=90)
  plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
df.columns
# Out:
# Index(['buying', 'maint', 'doors', 'persons', 'lug_boot', 'safety', 'Target'], dtype='object')

# %%
# COUNT PLOTS
test_cols = df.columns
for i in test_cols:
  for j in test_cols:
    sns.countplot(i, hue=j, data=df)
    plt.xticks(rotation=90)
    plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
# PROPORTION OF PEOPLE IN EACH TARGET CLASS SPLIT BY CATEGORIES
for j in test_cols:
  # print(df.value_counts([i, "wage"], normalize=True ).sort_index())
  print(df.groupby(j).agg({'Target':'value_counts'}).groupby(level=0).transform(lambda x: x.div(x.sum())))
  print("========================")
# Out:
#                  Target
# buying Target
# high   unacc   0.750000
#        acc     0.250000
# low    unacc   0.597222
#        acc     0.206019
#        good    0.106481
#        vgood   0.090278
# med    unacc   0.620370
#        acc     0.266204
#        vgood   0.060185
#        good    0.053241
# vhigh  unacc   0.833333
#        acc     0.166667
# ...
#                 Target
# maint Target
# high  unacc   0.726852
#       acc     0.243056
#       vgood   0.030093
# low   unacc   0.620370
#       acc     0.212963
#       good    0.106481
#       vgood   0.060185
# med   unacc   0.620370
#       acc     0.266204
#       vgood   0.060185
#       good    0.053241
# vhigh unacc   0.833333
#       acc     0.166667
# ...
#                 Target
# doors Target
# 2     unacc   0.754630
#       acc     0.187500
#       good    0.034722
#       vgood   0.023148
# 3     unacc   0.694444
#       acc     0.229167
#       good    0.041667
#       vgood   0.034722
# 4     unacc   0.675926
# ...

# %%
df.head() ## OBSERVNG A FEW SAMPLES FROM THE DATASET
# Out:
#   buying  maint doors persons lug_boot safety Target
# 0  vhigh  vhigh     2       2    small    low  unacc
# 1  vhigh  vhigh     2       2    small    med  unacc
# 2  vhigh  vhigh     2       2    small   high  unacc
# 3  vhigh  vhigh     2       2      med    low  unacc
# 4  vhigh  vhigh     2       2      med    med  unacc

# %%
# scatterplots

x = df.columns
y = df.columns
for n in y:
  for m in y:
   if n!=m:
    sns.scatterplot(y=m, x=n, data=df)
    plt.xticks(rotation=90) 
    plt.show()

# %%
#JOINT COUNT TABLES
x = df.columns
y = df.columns
for n in y:
  for m in y:
   if n!=m:
    x = df.pivot_table(columns=[n,m],aggfunc='size',fill_value=0)
    print(x)
# Out:
# buying  maint
# high    high     108
#         low      108
#         med      108
#         vhigh    108
# low     high     108
#         low      108
#         med      108
#         vhigh    108
# med     high     108
#         low      108
#         med      108
#         vhigh    108
# vhigh   high     108
#         low      108
#         med      108
#         vhigh    108
# dtype: int64
# buying  doors
# high    2        108
#         3        108
#         4        108
#         5more    108
# low     2        108
#         3        108
#         4        108
#         5more    108
# med     2        108
#         3        108
#         4        108
#         5more    108
# vhigh   2        108
#         3        108
#         4        108
#         5more    108
# dtype: int64
# buying  persons
# high    2          144
#         4          144
#         more       144
# low     2          144
#         4          144
#         more       144
# med     2          144
# ...

# %%
# REPLACING CATEGORICAL COLUMNS BY ENCODED VALUES
bm = {'vhigh':3, 'high':2, 'med':1, 'low':0}
d = {'2':2, '3':3, '4':4, '5more':5}
p = {'2':2, '4':4, 'more':5}
l = {'small':0, 'med':1, 'big':3}
s = {'low':0, 'med':1, 'high':2}
t = {'unacc':0, 'acc':1, 'vgood':3, 'good':2}

df = df.replace({
    'buying' : bm ,
'maint' : bm ,
'doors' : d ,
'persons' : p ,
'lug_boot' : l ,
'safety' : s ,
'Target' : t ,
})
df.head()
# Out:
#    buying  maint  doors  persons  lug_boot  safety  Target
# 0       3      3      2        2         0       0       0
# 1       3      3      2        2         0       1       0
# 2       3      3      2        2         0       2       0
# 3       3      3      2        2         1       0       0
# 4       3      3      2        2         1       1       0

# %%
# CREATING X AND Y
X = df.drop(['Target'], axis=1)
y = df['Target']

# %%
# HEATMAP OF CORRELATION AMONG FEATURES
sns.heatmap(df.corr(), annot=True)

# %%
# MODEL BUILDING
from sklearn.model_selection import cross_val_score
from sklearn.tree import DecisionTreeClassifier

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
clf = DecisionTreeClassifier(random_state=0)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
print("Number of mislabeled points out of a total %d points : %d"
      % (X_test.shape[0], (y_test != y_pred).sum()))
# Out:
# Number of mislabeled points out of a total 864 points : 38

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#          acc       0.95      0.92      0.93       193
#         good       0.97      0.72      0.83        40
#        unacc       0.98      0.98      0.98       599
#        vgood       0.71      0.91      0.79        32
#
#     accuracy                           0.96       864
#    macro avg       0.90      0.88      0.88       864
# weighted avg       0.96      0.96      0.96       864

# %%
#CONFUSION MATRIX
t_ = {0:'unacc', 1:'acc', 3:'vgood', 2:'good'}
y_test = y_test.replace(t_)
y_pred = pd.DataFrame(y_pred).replace(t_)
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)

# %% [markdown]
# # Plotting the tree

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(14,10))
plot_tree(clf)
plt.show()

# %%
# !pip install dtreeviz -q
# Out:
#      |████████████████████████████████| 61 kB 473 kB/s
# ...

# %%
from dtreeviz.trees import dtreeviz # remember to load the package

viz = dtreeviz(clf, X, y,
                target_name="Target",
                feature_names=X.columns,
                class_names=list(df.Target.unique()))

viz
# Out:
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
